# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 1400)
pd.set_option('display.max_columns', 110)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('~/Downloads/multigene_tests.csv')
# df.head()

## test type category from Q2
# DNA Gene-Expression Microarray
# Fragment Analysis
# IHC
# ISH
# Immunocytochemistry (ICC)
# Immunofluorescence (IF)
# Immunostaining
# Immunostaining/ISH
# Mass Spectrometry
# Microarray CGH
# NGS/FA/PCR
# Not Recorded
# Restriction Fragment Length Polymorphism
# Sequencing/PCR

# %% [markdown]
# ## Fixing elements in all tests
# Remove percentages from additional_result_1

# %%
# DONE 
# remove percentages from additional result 1
pct = df['additional_result_1'].str.contains('\%', na=False)


# preserve interpretation, null numeric
df.loc[pct,'record_status'] = 'suppress additional_result_1 and additional_result_1_unit, wrong numeric result collected; fixed biomarker_test_method'
df.loc[pct & (df['biomarker_name']!= 'MammaPrint Multi-biomarker Signature'),'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[pct & (df['biomarker_name']!= 'MammaPrint Multi-biomarker Signature'),'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[pct,'record_status_final'] = 'saved'
df.loc[pct,'additional_result_1'] = np.NaN
df.loc[pct,'additional_result_1_unit'] = np.NaN

# 9181 wrong interpretation;
# df.loc[df['Unnamed: 0']==9181]
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == '2.1%'
df.loc[bio & meth & bio & var & interp & num1,'test_result_interpretation'] = np.NaN
df.loc[bio & meth & bio & var & interp & num1,'test_result_interpretation'] = 'No'
df.loc[bio & meth & bio & var & interp & num1,'record_status'] = 'suppressed additional_result_1 and additional_result_1_unit, wrong numeric result collected; Changed test_result_interpretation to \'No\' per supporting narrative; fixed biomarker_test_method'
df.loc[bio & meth & bio & var & interp & num1,'record_status_final'] = 'saved'
# df.loc[bio & meth & bio & var & interp & num1]


# 498 supporting narrative not helpful
# df.loc[df['Unnamed: 0']==498]
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == '7.8 %'
df.loc[bio & meth & bio & var & interp & num1]
df.loc[bio & meth & bio & var & interp & num1,'record_status'] ='suppressed additional_result_1 and additional_result_1_unit, wrong numeric result collected; supporting narrative not helpful to confirm result'
df.loc[bio & meth & bio & var & interp & num1,'record_status_final'] = 'saved'

df[pct]
# Out:
#      Unnamed: 0                                biomarker_name            test_name                              biomarker_test_method biomarker_variant_type test_result_interpretation additional_result_1  additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source reporting_lab                               supporting_narrative data_source disease                                   InputFile                      methods_aw                                   record_status_aw                            biomarker_name_aw2        test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2  biomarker_variant_type_CAI                         biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2 test_result_interpretation_CAI additional_result_1_aw2 additional_result_1_unit_aw2  \
# ...

# %% [markdown]
# ## Remove other strings from additional_result_1_field

# %%
# fix other strings in additional result 1 numeric field
findstr = df['additional_result_1'].str.match('([a-zA-Z])')
df.loc[findstr==True]

# # 9571 - Prosigna IHC result, needs to be recurated, has string in additional result 1 and 2, and unit 1 and 2
bio = df['biomarker_name']=='Prosigna Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Immunohistochemistry Staining Method (IHC)'
var = df['biomarker_variant_type']=='Protein Expression'
interp = df['test_result_interpretation']=='Positive'
num1 = df['additional_result_1'] == 'strong'
df.loc[bio & meth & var & interp & num1,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1,'test_result_interpretation'] = np.NaN
df.loc[bio & meth & var & interp & num1,'biomarker_variant_type']=np.NaN
df.loc[bio & meth & var & interp & num1,'biomarker_variant_type']= 'Recurrence Risk Score'
df.loc[bio & meth & var & interp & num1,'biomarker_test_method'] = 'Gene Expression Microarray'
df.loc[bio & meth & var & interp & num1,'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
df.loc[bio & meth & var & interp & num1,'record_status'] = 'suppressed additional_result_1, additional_result_1_unit, additional_result_2 and additional_result_2_unit; results dont match test name'
df.loc[bio & meth & var & interp & num1,'record_status_final'] = 'recurate; record seems to be for PR result, not Prosigna test'
# df.loc[bio & meth & var & interp & num1]


# # 10273 - MammaPrint result interpretation 'Other' and luminal A as additional result 1 MPI as unit 1, need to recurate
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Not Recorded'
var = df['biomarker_variant_type']=='Not Recorded'
interp = df['test_result_interpretation']=='Other'
num1 = df['additional_result_1'] == 'luminal A'
df.loc[bio & meth & var & interp & num1,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1,'biomarker_test_method'] = 'Gene Expression Microarray'
df.loc[bio & meth & var & interp & num1,'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
df.loc[bio & meth & var & interp & num1,'biomarker_variant_type'] = np.NaN
df.loc[bio & meth & var & interp & num1,'biomarker_variant_type'] = 'Recurrence Risk Score'
df.loc[bio & meth & var & interp & num1,'record_status'] = 'suppressed additional_result_1, additional_result_1_unit, and test_result_interpretation; results dont match test name'
df.loc[bio & meth & var & interp & num1,'record_status_final'] = 'recurate; record seems to be result for BluePrint which is not collected'


# # 21617 - eRS only remove additional result 1 and unit 1, fix test_method
bio = df['biomarker_name']=='Estimated Recurrence Score (eRS)'
meth = df['biomarker_test_method']=='Immunohistochemistry Staining Method (IHC)'
var = df['biomarker_variant_type']=='Recurrence Score Estimate (eRS)'
interp = df['test_result_interpretation']=='Not Recorded'
num1 = df['additional_result_1'] == 'Not Recorded'
unit1 = df['additional_result_1_unit'] == 'Staining Intensity'
df.loc[bio & meth & var & interp & num1 & unit1]
df.loc[bio & meth & var & interp & num1 & unit1,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1,'biomarker_test_method'] = 'Breast eRS using Magee Equation'
df.loc[bio & meth & var & interp & num1 & unit1,'biomarker_test_type_category'] = 'IHC'
df.loc[bio & meth & var & interp & num1 & unit1,'record_status'] = 'suppressed additional_result_1 and additional_result_1_unit; additional numeric results were incorrect; fix biomarker_test_method'
df.loc[bio & meth & var & interp & num1 & unit1,'record_status_final'] = 'saved'

# # 11695 - Oncotype additional_result_1 and additional_result_2
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Not Recorded'
var = df['biomarker_variant_type']=='Not Recorded'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == 'Not Recorded'
num2 = df['additional_result_2'] == 4.0
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_variant_type'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_variant_type'] = 'Recurrence Risk Score'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'suppressed additional_result_1, additional_result_2 and additional_result_2_unit; additional numeric results were incorrect'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'saved'

# # 11788 - Oncotype move result 2 to result 1, change unit 1 to correct unit
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Not Recorded'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Not Recorded'
num1 = df['additional_result_1'] == 'Not Recorded'
num2 = df['additional_result_2'] == 21.0
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2']
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'moved additional_result_2 to additional_result_1; changed additional_result_1_unit to correct one'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'saved'
df.loc[bio & meth & var & interp & num1 & num2]

# # 14328 - Oncotype switch result 2 to result 1
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == 'Low'
num2 = df['additional_result_2'] == 7.0
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2']
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'moved additional_result_2 to additional_result_1'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'saved'

# # 14859 - Oncotype not sure if num 2 is correct, null num 1, unit 1 and num 2
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == 'Low'
num2 = df['additional_result_2'] == 19.0
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'suppressed additional_result_1, additional_result_1_unit and additional_result_2, additional_result_2_unit'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'recurate; result interpretation does not match numeric result'


# # 15672 - Oncotype change num 1 to num 2, correct unit, make interpretation not recorded
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Other'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'] == 'Not Recorded'
num2 = df['additional_result_2'] == 17.0
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'test_result_interpretation'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'test_result_interpretation'] = 'Not Recorded'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'suppressed additional_result_1 and additional_result_2; changed test_result_intepretation to \'Not Recorded\''
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'recurate; no supporting narrative to confirm numeric result is correct'


# # 23701 - Oncotype, change result to 'Not Recorded', change num 2 to num 1
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Not Recorded'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']== 'Intermediate'
num1 = df['additional_result_1'] == 'Low'
num2 = df['additional_result_2'] == 18.0
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2']
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'test_result_interpretation'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'test_result_interpretation'] = 'Not Recorded'
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'changed test_result_interpretation to \'Not Recorded\', additional_result_1 string and test_interpretation do not match; moved additional_result_2 to additional_result_1'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'saved'

# # 27434 - BCI mark for recuration, result not recorded and numeric is recurrence risk percentage
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']== 'Not Recorded'
num1 = df['additional_result_1'] == 'Not Recorded'
num2 = df['additional_result_2'] == 6.9
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'suppressed additional_result_1, additional_result_1_unit, and additional_result_2, additional_result_2_unit'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'recurate; numeric result is recurrence risk percentage, not score'

# # 10654 - Oncotype score presumably 13, but supporting narrative cannot be comprehended, need to recurate
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Not Recorded'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']== 'Low'
num1 = df['additional_result_1'] == 'Enter a valid string'
num2 = df['additional_result_2'] == 13.0
df.loc[bio & meth & var & interp & num1 & num2]
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & num2,'record_status'] = 'suppressed additional_result_1, additional_result_2, and additional_result_1_unit'
df.loc[bio & meth & var & interp & num1 & num2,'record_status_final'] = 'saved'

# # fixing the rest of the group
# df.loc[findstr==True& df['record_status_final'].isnull()]
df.loc[findstr==True & (df['record_status_final'].isnull()) & (df['biomarker_name'] != 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[findstr==True & (df['record_status_final'].isnull()) & (df['biomarker_name'] != 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[findstr==True & (df['record_status_final'].isnull()) & (df['biomarker_name'] == 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
df.loc[findstr==True& df['record_status_final'].isnull(),'additional_result_1'] = np.NaN
df.loc[findstr==True& df['record_status_final'].isnull(),'additional_result_1_unit'] = np.NaN
df.loc[findstr==True& df['record_status_final'].isnull(),'additional_result_2'] = np.NaN
df.loc[findstr==True& df['record_status_final'].isnull(),'record_status'] = 'suppressed additional_result_1 because it contained string not numeric; suppressed additional_result_1_unit didnt match numeric'
df.loc[findstr==True & (df['record_status_final'].isnull()) & (df['biomarker_name'] != 'MammaPrint Multi-biomarker Signature'),'record_status'] = 'suppressed additional_result_1 because it contained string not numeric; suppressed additional_result_1_unit didnt match numeric; fixed biomarker_test_method'
df.loc[findstr==True& df['record_status_final'].isnull(),'record_status_final'] = 'saved'

df.loc[(findstr==True) & (df['biomarker_name']!= 'Estimated Recurrence Score (eRS)') & ((df['biomarker_variant_type']=='Not Recorded') | (df['biomarker_variant_type']=='Recurrence Score Estimate (eRS)')),'biomarker_variant_type'] = np.NaN
df.loc[(findstr==True) & (df['biomarker_name']!= 'Estimated Recurrence Score (eRS)') & ((df['biomarker_variant_type']=='Not Recorded') | (df['biomarker_variant_type']=='Recurrence Score Estimate (eRS)')),'biomarker_variant_type'] = 'Recurrence Risk Score'
df.loc[findstr==True]
# Out:
#       Unnamed: 0                                biomarker_name                                   test_name                              biomarker_test_method           biomarker_variant_type test_result_interpretation   additional_result_1  additional_result_1_unit  additional_result_2    additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source   reporting_lab                               supporting_narrative data_source disease                                   InputFile                      methods_aw                                   record_status_aw                            biomarker_name_aw2                               test_name_aw2 reporting_lab_aw2  molecular_variant_aw2       biomarker_variant_type_aw2 biomarker_variant_type_CAI                         biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2  \
# ...

# %% [markdown]
# ## Fix all test records with
# - unit 1 and no numeric value in 1, and value in 2
# - no numeric value in 1 but has unit 1 and numeric value in 2
# - no numeric value in 1 but has unit 1 and no supporting narrative

# %%
# fix all test records with unit and no number
nonum1 = pd.isnull(df['additional_result_1'])
unit1 = pd.notnull(df['additional_result_1_unit'])
num2 = pd.notnull(df['additional_result_2'])
nosupport = pd.isnull(df['supporting_narrative'])

# has no num1 but has unit and has number in num 2 result
# df[nonum1 & unit1 & num2]
df.loc[nonum1 & unit1 & num2 & (df['biomarker_name'] != 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[nonum1 & unit1 & num2 & (df['biomarker_name'] != 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[nonum1 & unit1 & num2 & (df['biomarker_name'] == 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_method'] = 'Gene Expression Microarray'
df.loc[nonum1 & unit1 & num2 & (df['biomarker_name'] == 'MammaPrint Multi-biomarker Signature'), 'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
df.loc[nonum1 & unit1 & num2,'record_status'] = 'moved additional_result_2 to additional_result_1; fixed biomarker_test_method'
df.loc[nonum1 & unit1 & num2,'record_status_final'] = 'saved'
df.loc[nonum1 & unit1 & num2,'additional_result_1'] = df.loc[nonum1 & unit1 & num2,'additional_result_2']
df.loc[nonum1 & unit1 & num2,'additional_result_2'] = np.NaN

# 14616 - num in num 2 is percentage, not score. remove num2
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Quantitative Reverse Transcriptase PCR (RT-qPCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']== 'Low'
num1 = df['additional_result_1'].isnull()
num2 = df['additional_result_2'] == 6.0
df.loc[bio & meth & var & interp & num1 & num2, 'record_status'] = 'suppressed additional_result_1_unit and additional_result_2, numeric result is percentage not recurrence score; fixed biomarker_test_method'
df.loc[bio & meth & var & interp & num1 & num2, 'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2, 'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & num2, 'additional_result_2'] = np.NaN
# df[nonum1 & unit1 & num2]

################

# has null num1, has unit 1, but no supporting narrative
nonum1 = pd.isnull(df['additional_result_1'])
unit1 = pd.notnull(df['additional_result_1_unit'])
num2 = pd.notnull(df['additional_result_2'])
nosupport = pd.isnull(df['supporting_narrative'])

df.loc[nonum1 & unit1 & nosupport & (df['record_status_final'].isnull()),'record_status'] = 'suppressed additional_result_1_unit; no numeric result to go with unit; fixed biomarker_test_method'
df.loc[nonum1 & unit1 & nosupport & (df['record_status_final'].isnull()),'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[nonum1 & unit1 & nosupport & (df['record_status_final'].isnull()),'additional_result_1_unit'] = np.NaN
df.loc[nonum1 & unit1 & nosupport & (df['record_status_final'].isnull()),'record_status_final'] = 'saved'
# df[nonum1 & unit1 & nosupport]

#################

# 7229 - has unit1 and no number and no interpretation
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Not Recorded'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit']=='Recurrence Score Result'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'test_result_interpretation'] = 'Not Recorded'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_1_unit, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no test_result_interpretation'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'biomarker_test_type_category'] = 'Sequencing/PCR'


# has unit1 and no number but has interpretation
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Other'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit']=='Recurrence Score Result'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_1_unit, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'biomarker_test_type_category'] = 'Sequencing/PCR'


#################

# has null num1, has unit 1, num 2 but no supporting narrative

# 25418 - recurate; wrong Oncotype test, no numeric results but units in both 1 and 2, should be for AR-V7
bio = df['biomarker_name']=='Oncotype Dx Genomic Prostate Score Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Other'
var = df['biomarker_variant_type']=='Protein Expression'
interp = df['test_result_interpretation']=='Negative'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit']=='Percent of Cell Free DNA (cfDNA, %)'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_1_unit and additional_result_2_unit, no numeric results to go with units; wrong biomarker need to recurate'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; wrong biomarker test and wrong biomarker name, should be for AR-V7'


nonum1 = pd.isnull(df['additional_result_1'])
unit1 = pd.notnull(df['additional_result_1_unit'])
num2 = pd.notnull(df['additional_result_2'])
nosupport = pd.isnull(df['supporting_narrative'])

df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_variant_type']=='Not Recorded'),'biomarker_variant_type'] = 'Recurrence Risk Score'
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_variant_type']=='Not Recorded'),'biomarker_variant_type'] = np.NaN

df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_name']=='MammaPrint Multi-biomarker Signature'),'biomarker_test_method'] = 'Gene Expression Microarray'
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_name']=='MammaPrint Multi-biomarker Signature'),'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_name']!='MammaPrint Multi-biomarker Signature'),'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_name']!='MammaPrint Multi-biomarker Signature'),'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()) & (df['biomarker_name']!='MammaPrint Multi-biomarker Signature'),'record_status_final'] = 'recurate; no test_result_interpretation or numeric results'

df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()),'additional_result_1_unit'] = np.NaN
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()),'record_status'] = 'suppressed additional_result_1_unit, no numeric to go with unit'
df.loc[nonum1 & unit1 & (df['record_status_final'].isnull()),'record_status_final'] = 'saved'
df.loc[nonum1 & unit1]
# Out:
#       Unnamed: 0                                     biomarker_name                                   test_name                              biomarker_test_method biomarker_variant_type test_result_interpretation additional_result_1             additional_result_1_unit  additional_result_2         additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type                  doc_source   reporting_lab                               supporting_narrative data_source   disease                                   InputFile      methods_aw                                   record_status_aw                                 biomarker_name_aw2                               test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2 biomarker_variant_type_CAI                         biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2  \
# ...

# %%
# DONE fix tests with num and no unit

num1 = pd.notnull(df['additional_result_1'])
nounit1 = pd.isnull(df['additional_result_1_unit'])
df.loc[num1 & nounit1 & (df['record_status_final'].isnull())]

# # fixing variant type, test method
# for ind, row in df.loc[num1 & nounit1 & (df['record_status_final'].isnull())].iterrows():
#     if row['biomarker_variant_type']!= 'Recurrence Risk Score':
#         df.loc[ind,'biomarker_variant_type'] = np.NaN
#         df.loc[ind,'biomarker_variant_type'] = 'Recurrence Risk Score'

#     if 'Oncotype' in row['biomarker_name'] or 'Breast Cancer Index' in row['biomarker_name']:
#         df.loc[ind,'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
#         df.loc[ind,'biomarker_test_type_category'] = 'Sequencing/PCR'
#     elif 'Estimated' in row['biomarker_name']:
#         df.loc[ind,'biomarker_test_method'] = 'Breast eRS using Magee Equation'
#         df.loc[ind,'biomarker_test_type_category'] = 'IHC'
#         df.loc[ind,'biomarker_variant_type'] = 'Recurrence Score Estimate (eRS)'
#     else:
#         df.loc[ind,'biomarker_test_method'] = 'Gene Expression Microarray'
#         df.loc[ind,'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
    


# 10988 - Oncotype, cannot tell if number is score or percentage, remove numeric
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
test = df['test_name'] == 'Oncotype DX Breast Recurrence Score'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Not Recorded'
num1 = df['additional_result_1'] == '20'
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'].isnull()
df.loc[bio & test & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & test & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppress additional_result_1, supporting narrative not helpful to confirm result; fixed biomarker_variant_type and test_method'
df.loc[bio & test & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & test & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & test & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no test_result_interpretation and unclear numeric info'

# 18704 - BCI, numeric result different from supporting narrative, cannot tell which is truth, remove numeric
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == '2.2'
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppress additional_result_1, supporting narrative not helpful to confirm result; fixed biomarker_variant_type and test_method'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# 19270 - Oncotype numeric 1 very large unrealistic number, unit 2 numeric seems reasonable but no supporting narrative to confirm, remove both num 1 and 2
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Intermediate'
num1 = df['additional_result_1'] == '16326'
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2']== 21.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppress additional_result_1 and additional_result_2, 1 is unrealistic number and no supporting narrative to confirm 2; fixed biomarker_variant_type and test_method'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN  
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN 
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'
       
# 26141, 30413 - Mammaprint numeric has no unit, need to add MPI
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == '+0.369'
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'adding additional_result_1_unit to numeric result; fixed biomarker_variant_type and test_method'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = 'MammaPrint Index (MPI)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# 30413
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type']=='Recurrence Risk Score'
interp = df['test_result_interpretation']=='Low'
num1 = df['additional_result_1'] == '+0.457'
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'adding additional_result_1_unit to numeric result; fixed biomarker_variant_type and test_method'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = 'MammaPrint Index (MPI)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# the rest, just add unit to numeric 1
num1 = pd.notnull(df['additional_result_1'])
nounit1 = pd.isnull(df['additional_result_1_unit'])
df.loc[num1 & nounit1 & (df['record_status_final'].isnull())]
df.loc[num1 & nounit1 & (df['record_status_final'].isnull()),'record_status'] = 'adding additional_result_1_unit to numeric result; fixed biomarker_variant_type and test_method'
df.loc[num1 & nounit1 & (df['record_status_final'].isnull()),'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[num1 & nounit1 & (df['record_status_final'].isnull()),'record_status_final'] = 'saved'

# 7279 - make sure eRS unit is correct
bio = df['biomarker_name']=='Estimated Recurrence Score (eRS)'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Not Recorded'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'] == '18'
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = 'Estimated Risk Score (eRS)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1']
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'moving additional_result_1 to additional_result_2, fixed unit; fixed biomarker_test_method, biomarker_test_type_category, and biomarker_variant_type'


num1 = pd.notnull(df['additional_result_1'])
nounit1 = pd.isnull(df['additional_result_1_unit'])
df.loc[num1 & nounit1]
# Out:
#       Unnamed: 0                                biomarker_name                                          test_name                              biomarker_test_method           biomarker_variant_type test_result_interpretation   additional_result_1 additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source   reporting_lab                               supporting_narrative data_source disease                                   InputFile                      methods_aw                                   record_status_aw                            biomarker_name_aw2                                      test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2 biomarker_variant_type_CAI                          biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2  \
# ...

# %% [markdown]
# ## Fix Records with Null test_result_interpretation

# %%
df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull())]

# null interpretation, numeric 2 but no unit, no supporting narrative
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
test = df['test_name'].isnull()
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 29.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2]
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no units, no supporting_narrative'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no interpretation, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'test_result_interpretation'] = 'Not Recorded'


bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']=='Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 11.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no units, no supporting_narrative'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no interpretation, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'test_result_interpretation'] = 'Not Recorded'


bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 5.1
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no units, no supporting_narrative'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no interpretation, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'test_result_interpretation'] = 'Not Recorded'


bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 16.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no units, no supporting_narrative'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no interpretation, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'test_result_interpretation'] = 'Not Recorded'




# null interpretation, wrong numeric 2 and unit, no narrative
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Other'
var = df['biomarker_variant_type'] == 'Not Recorded'
interp = df['test_result_interpretation'].isnull()
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 21.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, wrong numeric units, no supporting_narrative'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] ='recurate; no interpretation, no numeric result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'test_result_interpretation'] = 'Not Recorded'


# fix the rest
df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()) & (df['biomarker_variant_type'] != 'Recurrence Risk Score'),'biomarker_variant_type']=np.NaN
df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()) & (df['biomarker_variant_type'] != 'Recurrence Risk Score'),'biomarker_variant_type']= 'Recurrence Risk Score'

df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()) & (df['biomarker_test_method'] != 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'),'biomarker_test_method']= 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()) & (df['biomarker_test_method'] != 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'),'biomarker_test_type_category']= 'Sequencing/PCR'

df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()),'record_status'] = 'change null test_result_interpretation to Not Recorded; fixed biomarker_test_method where needed'
df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()),'test_result_interpretation'] = 'Not Recorded'
df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull()),'record_status_final'] = 'saved'

# df.loc[(df['test_result_interpretation'].isnull()) & (df['record_status_final'].isnull())]

# %%
# x = df.loc[df['biomarker_name'] =='MammaPrint Multi-biomarker Signature']
# multigenes = {}
# multigenes['MammaPrint Multi-biomarker Signature'] = ['Gene Expression Microarray','Recurrence Risk Score','DNA Gene-Expression Microarray','MammaPrint Index (MPI)','Agendia']

# for bioname in multigenes.keys():
#     correct_method = multigenes[bioname][0]
#     correct_category = multigenes[bioname][2]
#     correct_variant = multigenes[bioname][1]
#     correct_unit = multigenes[bioname][3]
#     correct_lab = multigenes[bioname][4]
# #     print(bioname +"; "+ correct_method+"; " +correct_lab)
    
#     for ind,row in x.loc[x['biomarker_name']==bioname].iterrows():
#         # fixing variant type
#         if row['biomarker_variant_type'] != correct_variant:
#             x.loc[ind,'biomarker_variant_type'] = np.NaN
#             x.loc[ind,'biomarker_variant_type'] = correct_variant
            
#             if pd.isna(row['record_status_final']):
#                 x.loc[ind,'record_status_final'] = 'saved'
#             if pd.isna(row['record_status']):
#                 x.loc[ind,'record_status_final'] = 'test success'
#             else:
#                 x.loc[ind,'record_status'] = 'test success' + row['record_status'] 
        
        
                
# x

# %%
## Dictionary of lists for each multi-gene test, fixing all wrong test methods, variant types and additional result 1 units

multigenes = {}

# multigenes[bioname] = [ test_method, biomarker_variant_type, test_type_category, additional_result_1_unit, lab name]
multigenes['Breast Cancer Index'] = ['Quantitative Reverse Transcriptase PCR (RT-qPCR)','Endocrine Therapy Benefit','Sequencing/PCR','Recurrence Score Result','Other Lab']
multigenes['Decipher Prostate Multi-biomarker Signature'] = ['Gene Expression Microarray','Genetic Risk','DNA Gene-Expression Microarray','Decipher Score','Other Lab']
multigenes['EndoPredict'] = ['Quantitative Reverse Transcriptase PCR (RT-qPCR)','Recurrence Risk Score','Sequencing/PCR','EpClin risk score','Myriad Genetics']
multigenes['Estimated Recurrence Score (eRS)'] = ['Breast eRS using Magee Equation','Recurrence Score Estimate (eRS)','IHC','Estimated Risk Score (eRS)','Any']
multigenes['MammaPrint Multi-biomarker Signature'] = ['Gene Expression Microarray','Recurrence Risk Score','DNA Gene-Expression Microarray','MammaPrint Index (MPI)','Agendia']
multigenes['Oncotype Dx Breast Multi-biomarker Signature'] = ['Quantitative Reverse Transcriptase PCR (RT-qPCR)','Recurrence Risk Score','Sequencing/PCR','Recurrence Score Result','Genomic Health']
multigenes['Oncotype Dx DCIS Multi-biomarker Signature'] = ['Quantitative Reverse Transcriptase PCR (RT-qPCR)','Recurrence Risk Score','Sequencing/PCR','Recurrence Score Result','Genomic Health']
multigenes['Oncotype Dx Genomic Prostate Score Multi-biomarker Signature'] = ['Quantitative Reverse Transcriptase PCR (RT-qPCR)','Recurrence Risk Score','Sequencing/PCR','Genomic Prostate Score (GPS)','Genomic Health']
multigenes['Prolaris'] = ['Quantitative Reverse Transcriptase PCR (RT-qPCR)','Genetic Risk','Sequencing/PCR','Prolaris Molecular Score','Myriad Genetics']
multigenes['Prosigna Multi-biomarker Signature'] = ['Gene Expression Microarray','Recurrence Risk Score','DNA Gene-Expression Microarray','Recurrence Score Result','Any']


for bioname in multigenes.keys():
    correct_method = multigenes[bioname][0]
    correct_category = multigenes[bioname][2]
    correct_variant = multigenes[bioname][1]
    correct_unit = multigenes[bioname][3]
    correct_lab = multigenes[bioname][4]
    
    for ind,row in df.loc[df['biomarker_name']==bioname].iterrows():
        # fixing test method
        if row['biomarker_test_method'] != correct_method:
            df.loc[ind,'biomarker_test_method'] = correct_method
            df.loc[ind,'biomarker_test_type_category'] = correct_category
            
            if pd.isna(row['record_status_final']):
                df.loc[ind,'record_status_final'] = 'saved'
            if pd.isna(row['record_status']):
                df.loc[ind,'record_status'] = 'changed biomarker_test_method_name/biomarker_test_type_category to correct method'
            else:
                df.loc[ind,'record_status'] = row['record_status'] + '; changed biomarker_test_method_name/biomarker_test_type_category to correct method'
        
        # fixing test type category
        if (row['biomarker_test_method'] == correct_method) & (pd.notnull(row['biomarker_test_type_category'])):
            if row['biomarker_test_type_category'] != correct_category:
                df.loc[ind,'biomarker_test_type_category'] = correct_category
                
                if pd.isna(row['record_status_final']):
                    df.loc[ind,'record_status_final'] = 'saved'
                
                if pd.isna(row['record_status']):
                    df.loc[ind,'record_status'] = 'changed biomarker_test_type_category to correct method'
                else:
                    df.loc[ind,'record_status'] = row['record_status'] + '; changed biomarker_test_type_category to correct method'
        
        # fixing variant type
        if row['biomarker_variant_type'] != correct_variant:
            df.loc[ind,'biomarker_variant_type'] = np.NaN
            df.loc[ind,'biomarker_variant_type'] = correct_variant
            
            if pd.isna(row['record_status_final']):
                df.loc[ind,'record_status_final'] = 'saved'
            
            if pd.isna(row['record_status']):
                df.loc[ind,'record_status'] = 'suppressed biomarker_variant_type_name, changed to correct variant type'
            else:
                df.loc[ind,'record_status'] = row['record_status'] + '; suppressed biomarker_variant_type_name, changed to correct variant type'
        
        # fix units
        if bioname != 'Estimated Recurrence Score (eRS)':
            if (pd.notnull(row['additional_result_1'])) and (row['additional_result_1_unit'] != correct_unit):
                df.loc[ind,'additional_result_1_unit'] = correct_unit
                    
                if pd.notnull(row['record_status']):
                    df.loc[ind,'record_status'] = 'fixed additional_result_1_unit; ' + row['record_status']
                else:
                    df.loc[ind,'record_status'] = 'fixed additional_result_1_unit'
                
                if pd.isna(row['record_status_final']):
                    df.loc[ind,'record_status_final'] = 'saved'
        # fix labs
        if correct_lab != 'Any':            
            if row['reporting_lab'] != correct_lab or pd.isna(row['reporting_lab']):
                df.loc[ind,'reporting_lab'] = correct_lab
                
                if pd.notnull(row['record_status']):
                    df.loc[ind,'record_status'] =  row['record_status'] + '; fixed reporting_lab'
                else:
                    df.loc[ind,'record_status'] = 'fixed reporting_lab'
                        
                if pd.isna(row['record_status_final']):
                    df.loc[ind,'record_status_final'] = 'saved'

# %% [markdown]
# ## Breast Cancer Index

# %%
bioname = 'Breast Cancer Index'

# %%
# DONE fix the records with a number and no unit in unit 2
notnull = pd.notnull(df['additional_result_2'])
nounit = pd.isna(df['additional_result_2_unit'])

df.loc[(df['biomarker_name']==bioname) & notnull & nounit & (df['test_result_interpretation'] == 'No'),'record_status'] = 'moved additional_result_2 to additional_result_1, numeric result without unit; fixed biomarker_test_method'
df.loc[(df['biomarker_name']==bioname) & notnull & nounit & (df['test_result_interpretation'] == 'No'),'additional_result_1'] = df.loc[(df['biomarker_name']==bioname) & notnull & nounit & (df['test_result_interpretation'] == 'No'),'additional_result_2']
df.loc[(df['biomarker_name']==bioname) & notnull & nounit & (df['test_result_interpretation'] == 'No'),'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[(df['biomarker_name']==bioname) & notnull & nounit & (df['test_result_interpretation'] == 'No'),'additional_result_2'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & notnull & nounit & (df['test_result_interpretation'] == 'No'),'record_status_final'] = 'saved'


df.loc[(df['biomarker_name']==bioname) & notnull & nounit]
# Out:
#       Unnamed: 0       biomarker_name            test_name                              biomarker_test_method biomarker_variant_type test_result_interpretation additional_result_1 additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source reporting_lab                      supporting_narrative data_source disease                                   InputFile      methods_aw                                   record_status_aw   biomarker_name_aw2        test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2 biomarker_variant_type_CAI                         biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2 test_result_interpretation_CAI additional_result_1_aw2 additional_result_1_unit_aw2 additional_result_2_aw2 additional_result_2_unit_aw2 reagent_used_aw2  \
# ...

# %%
# DONE fix Negative result for BCI (only should be yes or no, high or low)
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'biomarker_test_method'] = 'Quantitative Reverse Transcriptase PCR (RT-qPCR)'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'biomarker_test_type_category'] = 'Sequencing/PCR'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'record_status'] = 'suppressed \'Negative\' result in test_result_interpretation; changed to \'No\'; suppressed additional_result_2; fixed biomarker_test_method'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'record_status_final'] = 'saved'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'additional_result_2'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'additional_result_2_unit'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'test_result_interpretation'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative'),'test_result_interpretation'] = 'No'

df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'] == 'Negative')]
# Out:
#     Unnamed: 0       biomarker_name            test_name                              biomarker_test_method biomarker_variant_type test_result_interpretation additional_result_1 additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source reporting_lab                           supporting_narrative data_source disease                                   InputFile      methods_aw                                   record_status_aw   biomarker_name_aw2        test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2 biomarker_variant_type_CAI                         biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2 test_result_interpretation_CAI additional_result_1_aw2 additional_result_1_unit_aw2 additional_result_2_aw2 additional_result_2_unit_aw2 reagent_used_aw2  \
# ...

# %%
# remove % positive cells from additional_2
#12416
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method'] == 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 4.6
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'suppress additional_result_2, incorrect numeric result collected'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'

# 16657
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method'] == 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 7.3
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'suppress additional_result_2, incorrect numeric result collected'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'

# 27762
bio = df['biomarker_name']=='Breast Cancer Index'
meth = df['biomarker_test_method'] == 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 9.5
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'suppress additional_result_2, incorrect numeric result collected'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'

# %%
#** need to check**
# fix wrong units
# df.loc[(df['biomarker_name']==bioname) & (df['additional_result_1_unit'] != 'Recurrence Score Result') & (df['additional_result_1'].notnull())]
# df.loc[(df['biomarker_name']==bioname) & (df['additional_result_1_unit'] != 'Recurrence Score Result') & (df['additional_result_1'].notnull()),'additional_result_1_unit'] = 'Recurrence Score Result'

for ind,row in df.loc[(df['biomarker_name']==bioname) & (df['additional_result_1_unit'] != 'Recurrence Score Result') & (df['additional_result_1'].notnull())].iterrows():
    if pd.isna(df.loc[ind,'record_status']):
        df.loc[ind,'record_status'] = 'fixed additional_result_1_unit'
    else:
        df.loc[ind,'record_status'] = 'fixed additional_result_1_unit; ' + row['record_status']
 

df.loc[(df['biomarker_name']==bioname) & (df['additional_result_1_unit'] != 'Recurrence Score Result') & (df['additional_result_1'].notnull()),'record_status_final'] = 'saved'
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_1_unit'] != 'Recurrence Score Result') & (df['additional_result_1'].notnull())]
# Out:
#       Unnamed: 0       biomarker_name                                          test_name                              biomarker_test_method     biomarker_variant_type test_result_interpretation additional_result_1   additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type                  doc_source reporting_lab                               supporting_narrative data_source disease                                   InputFile      methods_aw                                   record_status_aw   biomarker_name_aw2                                      test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2 biomarker_variant_type_CAI                         biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2 test_result_interpretation_CAI additional_result_1_aw2 additional_result_1_unit_aw2  \
# ...

# %% [markdown]
# ## MammaPrint

# %%
bioname = 'MammaPrint Multi-biomarker Signature'

# fixing results outside of MPI range
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'High'
num1 = df['additional_result_1'] == '94.6'
unit1 = df['additional_result_1_unit'] == 'MammaPrint Index (MPI)'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'biomarker_test_method'] = 'Gene Expression Microarray'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'biomarker_test_type_category'] = 'DNA Gene-Expression Microarray'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_1, MPI out of range; fixed biomarker_test_method'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Gene Expression Microarray'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'] == '10'
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_1, MPI out of range'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'] == 10.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, numeric in wrong field and MPI out of range'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Gene Expression Microarray'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'] == '+1.21'
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_1, MPI out of range'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# %%
# remove additional result 2
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull())]

# 6400, 23686 score in numeric 2, no units
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Other'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 0.293
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = df.loc[(df['Unnamed: 0']==6400),'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = 'MammaPrint Index (MPI)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'move additional_result_2 to additional_result_1, fixed units'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

#23686
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 0.335
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = df.loc[(df['Unnamed: 0']==23686),'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = 'MammaPrint Index (MPI)'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'move additional_result_2 to additional_result_1, fixed units' 
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


# fix the rest, remove num2 and unit 2
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull()),'additional_result_2_unit'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull()),'record_status'] = 'suppressed additional_result_2; wrong numeric results and units collected'
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull()),'record_status_final'] = 'saved'
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull()),'additional_result_2'] = np.NaN

# 1649
bio = df['biomarker_name']=='MammaPrint Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Not Recorded'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 70.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no test_result_interpretation, no numeric results'

# %%
# Remove the antibody clone 
bioname = 'MammaPrint Multi-biomarker Signature'
df.loc[(df['biomarker_name']==bioname) & (df['reagent_used'].notnull())]
df.loc[(df['biomarker_name']==bioname) & (df['reagent_used'].notnull()),'record_status']= df.loc[(df['biomarker_name']==bioname) & (df['reagent_used'].notnull()),'record_status'] + '; suppressed reagent_used, wrong info collected'
df.loc[(df['biomarker_name']==bioname) & (df['reagent_used'].notnull()),'reagent_used'] = np.NaN

# %%
bioname = 'MammaPrint Multi-biomarker Signature'

# fix test interpretation, should only be high, low, inconclusive, QNS, not recorded
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation']=='Negative'),'record_status'] = 'test_result_interpretation should only be high or low'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation']=='Negative'),'record_status_final'] = 'recurate; wrong test_result_interpretation'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation']=='Negative'),'test_result_interpretation'] = 'Not Recorded'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation']=='Negative'),'test_result_interpretation'] = np.NaN

# %% [markdown]
# ## Oncotype
# Wrong info in additional_result_2

# %%
bioname = 'Oncotype Dx Breast Multi-biomarker Signature'

#move recurrence scores to num 1
df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull()) & (df['record_status_final'].isnull())]

#####

#8785  - remove num 2, no supporting narrative
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Intermediate'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 14.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no supporting_narrative to confirm correct result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# 10279 
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'].isnull()
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Intermediate'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 23.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no supporting_narrative to confirm correct result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


# 9608
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 23.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no supporting_narrative to confirm correct result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# 16179
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 14.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no supporting_narrative to confirm correct result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


# 21853
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 16.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, no supporting_narrative to confirm correct result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


#####

# 10850 - remove num 2 and unit, leave num 1 as is
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'High'
num1 = df['additional_result_1'] == '49'
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'] == 32.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, wrong numeric results collect'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


# 19684
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'High'
num1 = df['additional_result_1'] == '48'
unit1 = df['additional_result_1_unit'] == 'Risk of Recurrence (ROR)'
num2 = df['additional_result_2'] == 48.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, wrong numeric results collect'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

# 28270
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'] == '26'
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'] == 26.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppressed additional_result_2, score recorded twice'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'

#####

# 12723 - change units, move num 2 to num 1
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Other'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'High'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 28.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1'] = df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'moved additional_result_2 to additional_result_1, fixed unit'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'


# 13247
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Other'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 10.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1'] = df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'moved additional_result_2 to additional_result_1, fixed unit'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'

#####

# 17247 - remove unit 2, fix unit1
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method'] == 'Other'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Intermediate'
num1 = df['additional_result_1'] == '21'
unit1 = df['additional_result_1_unit'] == 'Risk of Recurrence (ROR)'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_2_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppress additional_result_2_unit'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'saved'


# 19270 - score out of range, remove num 1 and 2, no units, no supporting narrative
# df.loc[df['Unnamed: 0']==19270, 'additional_result_1'] = np.NaN
# df.loc[df['Unnamed: 0']==19270, 'additional_result_2'] = np.NaN
# df.loc[df['Unnamed: 0']==19270,'record_status'] = 'suppressed additional_result_1 and additional_result_2, no units, no supporting_narrative'
# df.loc[df['Unnamed: 0']==19270,'record_status_final'] = 'saved'

#####

# 7188, 10816, 12476 - move num2 to num1, add units
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']== 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Intermediate'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 21.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1'] = df.loc[df['Unnamed: 0']==7188, 'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'moved additional_result_2 to additional_result_1, added units'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'


# 10816
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']== 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 14.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1'] = df.loc[df['Unnamed: 0']==7188, 'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'moved additional_result_2 to additional_result_1, added units'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'


# 12476
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']== 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'].isnull()
unit1 = df['additional_result_1_unit'].isnull()
num2 = df['additional_result_2'] == 25.0
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1'] = df.loc[df['Unnamed: 0']==7188, 'additional_result_2']
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_1_unit'] = 'Recurrence Score Result'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'additional_result_2'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status'] = 'moved additional_result_2 to additional_result_1, added units'
df.loc[bio & meth & var & interp & num1 & unit1 & num2, 'record_status_final'] = 'saved'



# df.loc[(df['biomarker_name']==bioname) & (df['additional_result_2'].notnull()) & (df['record_status_final'].isnull())]

# %%
#13307, 31241 - ranges not scores, remove num1
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']== 'Reverse Transcriptase-Polymerase Chain Reaction (RT-PCR)'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Not Recorded'
num1 = df['additional_result_1'] == '<31'
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppress additiona_result_1, range recorded, not actual score'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status_final'] = 'recurate; no test_result_interpretation and no numeric results'


# 31241
bio = df['biomarker_name']=='Oncotype Dx Breast Multi-biomarker Signature'
meth = df['biomarker_test_method']== 'Not Recorded'
var = df['biomarker_variant_type'] == 'Recurrence Risk Score'
interp = df['test_result_interpretation'] == 'Low'
num1 = df['additional_result_1'] == '0-17'
unit1 = df['additional_result_1_unit'] == 'Recurrence Score Result'
num2 = df['additional_result_2'].isnull()
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'additional_result_1_unit'] = np.NaN
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'suppress additiona_result_1, range recorded, not actual score'
df.loc[bio & meth & var & interp & num1 & unit1 & num2,'record_status'] = 'saved'

# %%
#clean up interpretation
bioname = 'Oncotype Dx Breast Multi-biomarker Signature'

l = ['No','Other','Moderate','Negative','No','Less Aggressive','Positive']  
wrong = '|'.join(l)
# df['NAME'].str.upper().str.contains(wrong)

df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'].str.contains(wrong)) & (df['test_result_interpretation']!= 'Not Recorded'),'test_result_interpretation'] = 'Not Recorded'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'].str.contains(wrong)) & (df['test_result_interpretation']!= 'Not Recorded'),'test_result_interpretation']= np.NaN
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'].str.contains(wrong)) & (df['test_result_interpretation']!= 'Not Recorded'),'record_status'] = 'suppress test_result_interpretation, incorrect value'
df.loc[(df['biomarker_name']==bioname) & (df['test_result_interpretation'].str.contains(wrong)) & (df['test_result_interpretation']!= 'Not Recorded'),'record_status_final'] = 'saved'

# %% [markdown]
# ## Prosigna
# Remove incorrect records that should be for PR not prosigna

# %%
bioname = 'Prosigna Multi-biomarker Signature'
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative'))]

df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'test_result_interpretation'] = 'Not Recorded'
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'record_status_final'] = 'recurate; record should be for PR not Prosigna'
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'record_status'] = 'suppress additional_result_1 and additional_result_2'
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'additional_result_1'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'additional_result_1_unit'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'additional_result_2'] = np.NaN
df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative')),'additional_result_2_unit'] = np.NaN

df.loc[(df['biomarker_name']==bioname) & ((df['test_result_interpretation']=='Positive')|(df['test_result_interpretation']=='Negative'))]
# Out:
#       Unnamed: 0                      biomarker_name     test_name                       biomarker_test_method biomarker_variant_type test_result_interpretation additional_result_1 additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source reporting_lab                               supporting_narrative data_source disease                                   InputFile    methods_aw                                   record_status_aw                  biomarker_name_aw2 test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2 biomarker_variant_type_CAI   biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2 test_result_interpretation_CAI additional_result_1_aw2 additional_result_1_unit_aw2 additional_result_2_aw2 additional_result_2_unit_aw2 reagent_used_aw2  \
# ...

# %% [markdown]
# ## eRS
# Wrong units, must be in additional_result_2

# %%
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit'].notnull())]

df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'record_status'] = 'moved additional_result_1 to additional_result_2, fixed units; ' + df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'record_status']
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'additional_result_1'] = np.NaN
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'additional_result_1_unit'] = np.NaN
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'additional_result_2'] = df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'additional_result_1']
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'additional_result_2_unit'] = 'Estimated Risk Score (eRS)'
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result'),'record_status_final'] = 'saved'



df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['additional_result_1_unit']=='Recurrence Score Result')]
# Out:
#      Unnamed: 0                    biomarker_name                                 test_name                       biomarker_test_method biomarker_variant_type test_result_interpretation additional_result_1 additional_result_1_unit  additional_result_2 additional_result_2_unit  molecular_variant  variant_classification  variant_category genomic_source_category reagent_used         specimen_type        doc_source reporting_lab                              supporting_narrative data_source disease                                   InputFile                       methods_aw                                   record_status_aw                biomarker_name_aw2                             test_name_aw2 reporting_lab_aw2  molecular_variant_aw2 biomarker_variant_type_aw2       biomarker_variant_type_CAI        biomarker_test_method_aw2 biomarker_test_type_category_CAI test_result_interpretation_aw2 test_result_interpretation_CAI additional_result_1_aw2 additional_result_1_unit_aw2  \
# ...

# %%
# remove incorrect result interp
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['test_result_interpretation']=='No'),'record_status'] = 'suppress incorrect test_result_interpretation'
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['test_result_interpretation']=='No'),'record_status_final'] = 'saved'
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['test_result_interpretation']=='No'),'test_result_interpretation'] = np.NaN
df.loc[(df['biomarker_name']=='Estimated Recurrence Score (eRS)') & (df['test_result_interpretation']=='No'),'test_result_interpretation'] = 'Not Recorded'

# %% [markdown]
# ## Final Fixes

# %%
# final status if no numeric or interpretation then mark for recuration
# nonum1 = pd.isnull(df['additional_result_1'])
# nonum2 = pd.isnull(df['additional_result_2'])

# # df.loc[((df['test_result_interpretation']=='Not Recorded')|(df['test_result_interpretation']=='Not Recorded'))\
# #        & nonum1 & nonum2 ,'record_status_final'] = 'recurate; no numeric or interpretation results'

# df.loc[((df['test_result_interpretation']=='Not Recorded')|(df['test_result_interpretation']=='Not Recorded'))\
#        & nonum1 & nonum2 ,'record_status_final']

# %%
df.loc[(df['record_status_final'].isnull()) & (df['record_status'].isnull()),'record_status_final'] = 'ok'
# df.loc[(df['record_status_final'].isnull()) & (df['record_status'].isnull())]

# %%
df.to_csv('testing_cleaned_multigene.csv',na_rep='',doublequote=False)
